# %% [markdown]
# # Lecture 14
#
# # Pandas: Indexing, Arithmetic, Missing Values
#
# ## Week 5 Wednesday
#
# ## Miles Chen, PhD
#
# Based on Wes McKinney's Python for Data Analysis and the Pandas Documentation

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Series that we will use as examples

# %%
# note that the value after the decimal place corresponds to the letter position.
# i.e. 1.4 corresponds to d, the fourth letter.
original1 = pd.Series([1.4, 2.3, 3.1, 4.2], index = ['d','c','a','b'])
original2 = pd.Series([2.2, 3.1, 1.3, 4.4], index = ['b','a','c','d'])

# %%
original1 # when you create a series, the original order of the index is preserved
# Out:
# d    1.4
# c    2.3
# a    3.1
# b    4.2
# dtype: float64

# %%
# making a DataFrame with multiple series with the same index preserves the index order
pd.DataFrame({"x":original1, "x2": original1 * 2})
# Out:
#      x   x2
# d  1.4  2.8
# c  2.3  4.6
# a  3.1  6.2
# b  4.2  8.4

# %%
original2 # note that original1 and original2 have different index orders
# Out:
# b    2.2
# a    3.1
# c    1.3
# d    4.4
# dtype: float64

# %%
# because original1 and original2 have index in different order, Pandas will sort the index before putting them together
df = pd.DataFrame({"x":original1, "y": original2})
df
# Out:
#      x    y
# a  3.1  3.1
# b  4.2  2.2
# c  2.3  1.3
# d  1.4  4.4

# %%
original1.index # the index of original1 is the letters d, c, a, b in a tuple-like object
# Out:
# Index(['d', 'c', 'a', 'b'], dtype='str')

# %%
original1['d':'a'] # when slicing pandas uses the index order or original1
# Out:
# d    1.4
# c    2.3
# a    3.1
# dtype: float64

# %%
df.index  # the index of df are the letters abcd in order
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='str')

# %%
df['a':'c'] # when slicing Pandas uses the index order of the DataFrame, which has been sorted
# Out:
#      x    y
# a  3.1  3.1
# b  4.2  2.2
# c  2.3  1.3

# %% [markdown]
# ## Rearranging value
#
# Both Series and DataFrames have the `.sort_index()` and `.sort_values()` methods which can be used to rearrange the value.

# %%
original2
# Out:
# b    2.2
# a    3.1
# c    1.3
# d    4.4
# dtype: float64

# %%
original2.sort_index()
# Out:
# a    3.1
# b    2.2
# c    1.3
# d    4.4
# dtype: float64

# %%
original2.sort_values()
# Out:
# c    1.3
# b    2.2
# a    3.1
# d    4.4
# dtype: float64

# %%
original2
# Out:
# b    2.2
# a    3.1
# c    1.3
# d    4.4
# dtype: float64

# %%
df
# Out:
#      x    y
# a  3.1  3.1
# b  4.2  2.2
# c  2.3  1.3
# d  1.4  4.4

# %%
df.sort_values(by = "x", ascending = False)
# Out:
#      x    y
# b  4.2  2.2
# a  3.1  3.1
# c  2.3  1.3
# d  1.4  4.4

# %% [markdown]
# # Changing the Index

# %% [markdown]
# The index of a Pandas Series or Pandas DataFrame is immutable and cannot be modified.
#
# However, if you want to change the index of a series or dataframe, you can define a new index and replace the existing index of the series/DataFrame.

# %%
original1.index = range(4) # I replace the index of the series with this range object.

# %%
original1
# Out:
# 0    1.4
# 1    2.3
# 2    3.1
# 3    4.2
# dtype: float64

# %%
original1.index # We can see this has automatically become a RangeIndex object
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
original1[1]
# Out:
# np.float64(2.3)

# %%
original1.loc[1] # behaves the same as above
# Out:
# np.float64(2.3)

# %%
original1.iloc[1] # behaves the same as above because the range index starts at 0
# Out:
# np.float64(2.3)

# %%
original1.index = range(1,5)

# %%
original1
# Out:
# 1    1.4
# 2    2.3
# 3    3.1
# 4    4.2
# dtype: float64

# %%
original1[1]
# Out:
# np.float64(1.4)

# %%
original1.loc[1]
# Out:
# np.float64(1.4)

# %%
original1.iloc[1] # behavior is different because range index starts at 1
# Out:
# np.float64(2.3)

# %%
original1['a'] # throws an error because 'a' is no longer part of the index and cannot be used to select values
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 original1['a'] # throws an error because 'a' is no longer part of the index and cannot be used to select values
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexes\range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'a'

# %%
original1.index = ['a','b','c','d'] # be careful as no restrictions regarding the meaning of the index is applied.
# in the original 'a' was associated with 3.1. This index will associate it with 1.4

# %%
original1
# Out:
# a    1.4
# b    2.3
# c    3.1
# d    4.2
# dtype: float64

# %%
original1['a']
# Out:
# np.float64(1.4)

# %%
original1[0] # no 'a' in the index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 original1[0] # no 'a' in the index
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 0

# %%
original1.index = [1, 2, 3, 4, 5] # if the object you provide is of a different length, you get a value error
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 original1.index = [1, 2, 3, 4, 5] # if the object you provide is of a different length, you get a value error
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\generic.py:6221, in NDFrame.__setattr__(self, name, value)
#    6217
#    6218         try:
#    6219             object.__getattribute__(self, name)
#    6220             return object.__setattr__(self, name, value)
# -> 6221         except AttributeError:
#    6222             pass
#    6223
#    6224         # if this fails, go on to more involved attribute setting
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
# ---> 69 'Could not get source, probably due dynamically evaluated source code.'
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\generic.py:766, in NDFrame._set_axis(self, axis, labels)
#     762         This is called from the cython code when we set the `index` attribute
#     763         directly, e.g. `series.index = [1, 2, 3]`.
#     764         """
#     765         labels = ensure_index(labels)
# --> 766         self._mgr.set_axis(axis, labels)
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\internals\managers.py:273, in BaseBlockManager.set_axis(self, axis, new_labels)
#     271 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     272     # Caller is responsible for ensuring we have an Index object.
# --> 273     self._validate_set_axis(axis, new_labels)
#     274     self.axes[axis] = new_labels
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\internals\managers.py:288, in BaseBlockManager._validate_set_axis(self, axis, new_labels)
#     285     pass
#     287 elif new_len != old_len:
# --> 288     raise ValueError(
#     289         f"Length mismatch: Expected axis has {old_len} elements, new "
#     290         f"values have {new_len} elements"
#     291     )
#
# ValueError: Length mismatch: Expected axis has 4 elements, new values have 5 elements

# %%
# similarly you can change the index of a DataFrame by defining a new object and assigning it to the index.
df.index = ['j','k','l','m']
df
# Out:
#      x    y
# j  3.1  3.1
# k  4.2  2.2
# l  2.3  1.3
# m  1.4  4.4

# %% [markdown]
# # Reindexing
#
# Reindexing is different from just defining a new index.
#
# Reindexing takes a current Pandas object and creates a *new* Pandas object that *conforms* to the specified index.
#
# **Do not confuse reindexing with creating a new index for a dataframe object.**

# %%
original = pd.Series([1.4, 2.3, 3.1, 4.2], index = ['d','c','a','b'])

# %%
original
# Out:
# d    1.4
# c    2.3
# a    3.1
# b    4.2
# dtype: float64

# %%
newobj = original.reindex(['a','b','c','d','e']) # note this has an index value that doesn't exist in the original series

# %%
newobj  # takes the data in orignal and moves it so it conforms to the specified index
# values that do not exist for the new index get NaN
# Out:
# a    3.1
# b    4.2
# c    2.3
# d    1.4
# e    NaN
# dtype: float64

# %%
# if you don't want NaN, you can specify a fill_value
newobj2 = original.reindex(['a','b','c','d','e'], fill_value = 0)
newobj2
# Out:
# a    3.1
# b    4.2
# c    2.3
# d    1.4
# e    0.0
# dtype: float64

# %% [markdown]
# For ordered data like a time series, it might be desirable to fill values when reindexing

# %%
obj3 = pd.Series(['blue', 'purple', 'yellow'], index=[0, 3, 6])
obj3
# Out:
# 0      blue
# 3    purple
# 6    yellow
# dtype: str

# %%
obj3.reindex(range(9))  # without any optional arguments, lots of missing values
# Out:
# 0      blue
# 1       NaN
# 2       NaN
# 3    purple
# 4       NaN
# 5       NaN
# 6    yellow
# 7       NaN
# 8       NaN
# dtype: str

# %%
obj3.reindex(range(9), method='ffill')
# forward-fill pushes values 'forward' until a new value is encountered
# Out:
# 0      blue
# 1      blue
# 2      blue
# 3    purple
# 4    purple
# 5    purple
# 6    yellow
# 7    yellow
# 8    yellow
# dtype: str

# %%
obj3.reindex(range(9), method='bfill')  
# back-fill works in the opposite direction
# there was no value at index 8 so, NaNs get filled in
# Out:
# 0      blue
# 1    purple
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# 6    yellow
# 7       NaN
# 8       NaN
# dtype: str

# %% [markdown]
# ## Date Ranges as Index

# %%
# we specify the creation of a date_index using the date_range function
# freq = 'D' creates Daily values 
date_index = pd.date_range('1/1/2010', periods=6, freq='D')
date_index
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-02', '2010-01-03', '2010-01-04',
#                '2010-01-05', '2010-01-06'],
#               dtype='datetime64[us]', freq='D')

# %%
# we create a DataFrame with the date index
df2 = pd.DataFrame({"prices": [100, 101, np.nan, 100, 89, 88]}, index=date_index)
df2
# Out:
#             prices
# 2010-01-01   100.0
# 2010-01-02   101.0
# 2010-01-03     NaN
# 2010-01-04   100.0
# 2010-01-05    89.0
# 2010-01-06    88.0

# %%
date_index2 = pd.date_range('12/29/2009', periods=10, freq='D')  # a new date index
df2.reindex(date_index2)
# Out:
#             prices
# 2009-12-29     NaN
# 2009-12-30     NaN
# 2009-12-31     NaN
# 2010-01-01   100.0
# 2010-01-02   101.0
# 2010-01-03     NaN
# 2010-01-04   100.0
# 2010-01-05    89.0
# 2010-01-06    88.0
# 2010-01-07     NaN

# %%
df2.reindex(date_index2, method = 'bfill') 
# The value for Jan 3 isn't filled in because that NaN was not created by the reindexing process
# The NaN already existed in the data.
# Out:
#             prices
# 2009-12-29   100.0
# 2009-12-30   100.0
# 2009-12-31   100.0
# 2010-01-01   100.0
# 2010-01-02   101.0
# 2010-01-03     NaN
# 2010-01-04   100.0
# 2010-01-05    89.0
# 2010-01-06    88.0
# 2010-01-07     NaN

# %% [markdown]
# ## `.reindex()` vs `.loc()`
#
# If you don't need to fill in any missing info, then `.reindex()` and `.loc()` work very similarly.
# If the new index will have values that don't exist in the current index, you need to use `reindex`.

# %%
obj5 = pd.DataFrame({'val':[1.4, 2.3, 3.1, 4.2]}, index = ['d','c','a','b'])
obj5
# Out:
#    val
# d  1.4
# c  2.3
# a  3.1
# b  4.2

# %%
obj5.reindex(['a','b','c','d'])
# Out:
#    val
# a  3.1
# b  4.2
# c  2.3
# d  1.4

# %%
obj5.loc[['a','b','c','d']] # works the same as reindex
# Out:
#    val
# a  3.1
# b  4.2
# c  2.3
# d  1.4

# %%
obj5.reindex(['a','b','c','d','e'])
# Out:
#    val
# a  3.1
# b  4.2
# c  2.3
# d  1.4
# e  NaN

# %%
obj5.loc[['a','b','c','d','e']]  # .loc() returns an error if you give an entry in the index that doesn't exist
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 obj5.loc[['a','b','c','d','e']]  # .loc() returns an error if you give an entry in the index that doesn't exist
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexing.py:1438, in _LocIndexer._getitem_axis(self, key, axis)
#    1435     if hasattr(key, "ndim") and key.ndim > 1:
#    1436         raise ValueError("Cannot index with multidimensional key")
# -> 1438     return self._getitem_iterable(key, axis=axis)
#    1440 # nested tuple slicing
#    1441 if is_nested_tuple(key, labels):
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexing.py:1378, in _LocIndexer._getitem_iterable(self, key, axis)
#    1375 self._validate_key(key, axis)
#    1377 # A collection of keys
# -> 1378 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1379 return self.obj._reindex_with_indexers(
#    1380     {axis: [keyarr, indexer]}, allow_dups=True
#    1381 )
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexing.py:1576, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1573 ax = self.obj._get_axis(axis)
#    1574 axis_name = self.obj._get_axis_name(axis)
# -> 1576 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1578 return keyarr, indexer
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['e'] not in index"

# %% [markdown]
# # Dropping rows or columns
#
# you can use `df.drop()` to remove rows (default) or columns (specify axis = 1) at certain index locations.

# %%
df = pd.DataFrame(np.arange(12).reshape(3,4), columns=['A', 'B', 'C', 'D'], index = ['x','y','z'])
df
# Out:
#    A  B   C   D
# x  0  1   2   3
# y  4  5   6   7
# z  8  9  10  11

# %%
# drop rows
df.drop(['x', 'z'])
# Out:
#    A  B  C  D
# y  4  5  6  7

# %%
# drop columns
df.drop(columns=['B', 'C'])
# Out:
#    A   D
# x  0   3
# y  4   7
# z  8  11

# %%
# df.drop returns a new object and leaves df unchanged
df
# Out:
#    A  B   C   D
# x  0  1   2   3
# y  4  5   6   7
# z  8  9  10  11

# %% [markdown]
# # Data Alignment
#
# When performing element-wise arithmetic, Pandas will align the index values before doing the computation

# %%
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=['a', 'c', 'd', 'e'])
s1
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1],
               index=['a', 'c', 'e', 'f', 'g'])
s2
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %%
pd.DataFrame({'s1':s1,'s2':s2}) # for reference
# Out:
#     s1   s2
# a  7.3 -2.1
# c -2.5  3.6
# d  3.4  NaN
# e  1.5 -1.5
# f  NaN  4.0
# g  NaN  3.1

# %%
s1 + s2  # returns a new series, where the indexes are the union of the indexes of s1 and s2
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
s1.add(s2)
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
pd.DataFrame({'s1':s1,'s2':s2})
# Out:
#     s1   s2
# a  7.3 -2.1
# c -2.5  3.6
# d  3.4  NaN
# e  1.5 -1.5
# f  NaN  4.0
# g  NaN  3.1

# %%
s1.sub(s2, fill_value = 0)
# Out:
# a    9.4
# c   -6.1
# d    3.4
# e    3.0
# f   -4.0
# g   -3.1
# dtype: float64

# %%
s1.rsub(s2, fill_value = 0) # .rsub means 'right hand subtract' sets the series in the argument as the base
# Out:
# a   -9.4
# c    6.1
# d   -3.4
# e   -3.0
# f    4.0
# g    3.1
# dtype: float64

# %%
s1 * s2
# Out:
# a   -15.33
# c    -9.00
# d      NaN
# e    -2.25
# f      NaN
# g      NaN
# dtype: float64

# %%
s1.multiply(s2, fill_value = 1)
# Out:
# a   -15.33
# c    -9.00
# d     3.40
# e    -2.25
# f     4.00
# g     3.10
# dtype: float64

# %% [markdown]
# For data frames with different columns, the rows and columns will be aligned

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list('bcd'),
                   index=['Ohio', 'Texas', 'Colorado'])
df1
# Out:
#             b    c    d
# Ohio      0.0  1.0  2.0
# Texas     3.0  4.0  5.0
# Colorado  6.0  7.0  8.0

# %%
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list('bde'),
                   index=['Utah', 'Ohio', 'Texas', 'Oregon'])
df2
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
df1 + df2 
# c is in df1, but not df2
# e is in df2, but not df1
# the result returns the union of columns, but will fill in NaN for elements that do not exist in both
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
# if you want to fill in values that are missing, you can use df.add() and specify the fill_value
# this will perform the above operation, but instead of using NaN when it can't find a value 
# (which will return NaN),
# it will use the fill_value
df1.add(df2, fill_value = 0)
# you still get NaN if the value does not exist in either DataFrame
# Out:
#             b    c     d     e
# Colorado  6.0  7.0   8.0   NaN
# Ohio      3.0  1.0   6.0   5.0
# Oregon    9.0  NaN  10.0  11.0
# Texas     9.0  4.0  12.0   8.0
# Utah      0.0  NaN   1.0   2.0

# %% [markdown]
# Arithmetic operations that can be called on DataFrames and Series are:
#
# - `.add()`, `.radd()` and `.sub()`, `.rsub()`
# - `.mul()`, `.rmul()` and `.div()`, `.rdiv()`
# - `.floordiv()`, `.rfloordiv()` (floor division `//`)
# - `.pow()`, `.rpow()` (exponentiation `**`)

# %% [markdown]
# # Summary Stats of a DataFrame

# %%
df = pd.DataFrame({'one':[1.5,6.0,np.nan, 1.5,4,6, np.nan],
                   'two':[np.nan, -4.5, np.nan, -1.5, 0, -4.5, 4]},
                  index=['a', 'b', 'c', 'd','e','f','g'])
df
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.sum()  # default behavior returns column sums and skips missing values
# default behavior sums across axis 0 (sums the row)
# Out:
# one    19.0
# two    -6.5
# dtype: float64

# %%
df # for reference
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.sum(axis = 1) # sum across axis=1, sum across the columns and give row sums
# Out:
# a    1.5
# b    1.5
# c    0.0
# d    0.0
# e    4.0
# f    1.5
# g    4.0
# dtype: float64

# %%
df.sum(skipna = False)
# Out:
# one   NaN
# two   NaN
# dtype: float64

# %%
df.mean()
# Out:
# one    3.8
# two   -1.3
# dtype: float64

# %%
df.mean(axis = 1)
# Out:
# a    1.50
# b    0.75
# c     NaN
# d    0.00
# e    2.00
# f    0.75
# g    4.00
# dtype: float64

# %%
df # for reference
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.min()
# Out:
# one    1.5
# two   -4.5
# dtype: float64

# %%
df.idxmin()  # which row has the minimum value, also .idxmax()
# returns the first minimum, if there are multiple
# you can also specify axis
# Out:
# one    a
# two    b
# dtype: str

# %% [markdown]
# ## Summary stats available for dataframes and series
#
# - `count()` - number of non NA values
# - `quantile()`
# - `sum()`
# - `mean()`
# - `median()`
# - `prod()`
# - `var()`, `std()`
#
# https://pandas.pydata.org/pandas-docs/stable/reference/series.html#computations-descriptive-stats

# %% [markdown]
# ## Unique values

# %%
df # for reference
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.one.unique()  # shows the unique values in the order observed
# Out:
# array([1.5, 6. , nan, 4. ])

# %%
df.two.unique()
# Out:
# array([ nan, -4.5, -1.5,  0. ,  4. ])

# %%
df.unique()  # unique can only be applied to a series (a column in a dataframe)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df.unique()  # unique can only be applied to a series (a column in a dataframe)
#
# File c:\Users\miles\OneDrive\Teaching\21\26-spring-stats-21\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df # for reference
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.one.nunique()  # number of non-missing unique values exist
# Out:
# 3

# %%
df.one.value_counts()  # tally up counts of each value
# returns a series. the index are the unique values observed, the values are the frequencies.
# they appear in descending order of frequency
# Out:
# one
# 1.5    2
# 6.0    2
# 4.0    1
# Name: count, dtype: int64

# %%
df.one.isin([1.5, 4.0]) # checks to see if the value has membership in a particular list
# returns a series with boolean values
# Out:
# a     True
# b    False
# c    False
# d     True
# e     True
# f    False
# g    False
# Name: one, dtype: bool

# %%
(df.one == 1.5) | (df.one == 4.0)  # must use bitwise or. .isin() is much prefered
# Out:
# a     True
# b    False
# c    False
# d     True
# e     True
# f    False
# g    False
# Name: one, dtype: bool

# %%
df.loc[  df.one.isin([1.5,4.0]),  ]  # can filter rows based on the .isin() membership
# Out:
#    one  two
# a  1.5  NaN
# d  1.5 -1.5
# e  4.0  0.0

# %% [markdown]
# # filtering out missing values

# %%
df
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.dropna() # gets rid of any row that is not complete
# Out:
#    one  two
# b  6.0 -4.5
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5

# %%
df.dropna(how = 'all')  # only drops rows that are entirely NaN
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
# you can also use .notnull(), which is True for values that are not missing
df[df.two.notnull()]  # You can use this in conjuntion with specifying the column
# Out:
#    one  two
# b  6.0 -4.5
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %% [markdown]
# # Filling in Missing Values

# %%
df
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.fillna(0) # fill in missing values with a constant
# Out:
#    one  two
# a  1.5  0.0
# b  6.0 -4.5
# c  0.0  0.0
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  0.0  4.0

# %%
df.fillna({'one': 1000, 'two': 0})  # use a dictionary to specify values to use for each column
# Out:
#       one  two
# a     1.5  0.0
# b     6.0 -4.5
# c  1000.0  0.0
# d     1.5 -1.5
# e     4.0  0.0
# f     6.0 -4.5
# g  1000.0  4.0

# %%
df.bfill() # backfills missing values
# Out:
#    one  two
# a  1.5 -4.5
# b  6.0 -4.5
# c  1.5 -1.5
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.ffill() # forward fills missing values
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  6.0 -4.5
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  6.0  4.0

# %%
df.mean()
# Out:
# one    3.8
# two   -1.3
# dtype: float64

# %%
df.fillna(df.mean())  # fill na with df.mean() will fill in the column means
# Out:
#    one  two
# a  1.5 -1.3
# b  6.0 -4.5
# c  3.8 -1.3
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  3.8  4.0

# %% [markdown]
# all of the above fillna methods have created new copies of DataFrame objects

# %%
df.T
# Out:
#        a    b   c    d    e    f    g
# one  1.5  6.0 NaN  1.5  4.0  6.0  NaN
# two  NaN -4.5 NaN -1.5  0.0 -4.5  4.0

# %%
# apparently you can only fill missing values with dictionaries/series over a column 
# so we have to do some Transpose magic
df.T.fillna(df.T.mean()).T
# Out:
#    one  two
# a  1.5  1.5
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  4.0  4.0

# %% [markdown]
# # dealing with duplicates

# %%
df
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# f  6.0 -4.5
# g  NaN  4.0

# %%
df.duplicated()  # sees if any of the rows are a duplicate of an earlier row
# Out:
# a    False
# b    False
# c    False
# d    False
# e    False
# f     True
# g    False
# dtype: bool

# %%
df[~df.duplicated()]  # gets rid of the duplicated rows
# Out:
#    one  two
# a  1.5  NaN
# b  6.0 -4.5
# c  NaN  NaN
# d  1.5 -1.5
# e  4.0  0.0
# g  NaN  4.0

# %%
df.one.duplicated()
# Out:
# a    False
# b    False
# c    False
# d     True
# e    False
# f     True
# g     True
# Name: one, dtype: bool
